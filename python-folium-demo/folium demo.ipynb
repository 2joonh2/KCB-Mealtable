# %%
import folium
import pandas as pd

# %%
nearby_res=pd.read_csv('C:\\Users\\2joon\\Research\\NYC 14K restaurants\\nearby restaurants\\542_nearby_res.csv')
nearby_res.head()
# Out:
#    Unnamed: 0                                         scrapedurl  \
# 0          40   https://www.yelp.com/biz/2-bros-pizza-new-york-3
# 1          68  https://www.yelp.com/biz/33-gourmet-deli-new-york
# 2          83        https://www.yelp.com/biz/48-lounge-new-york
# 3          90  https://www.yelp.com/biz/5-napkin-burger-new-y...
# 4         102    https://www.yelp.com/biz/5th-and-mad-new-york-2
#
#                                    yelpid             name  closed   verified  \
# 0                 2-bros-pizza-new-york-3     2 Bros Pizza   False    Claimed
# 1                33-gourmet-deli-new-york  33 Gourmet Deli   False  Unclaimed
# 2                      48-lounge-new-york        48 Lounge   False    Claimed
# 3  5-napkin-burger-hells-kitchen-new-york  5 Napkin Burger   False    Claimed
# 4                  5th-and-mad-new-york-2        5th & Mad   False    Claimed
#
#    rating  review pricerange                    categorylist  photos  \
# ...

# %%
df=pd.read_csv('C:\\Users\\2joon\\Research\\NYT reviews_processed_revised.csv', index_col=0)
df
# Out:
#                       name  nyt_price            nyt_neighborhood nyt_critic  \
# 0             Thirty Acres        3.0                 Jersey City      Wells
# 1    Carnitas El Atoradero        1.0                  Mott Haven     Mishan
# 2               Mexicocina        1.0              North New York     Mishan
# 3                La Morada        1.0              North New York     Mishan
# 4                   Patina        1.0  Fairmont-Claremont Village     Mishan
# ..                     ...        ...                         ...        ...
# 829   VIOLET'S BAKE SHOPPE        1.0                Forest Hills     Mishan
# 830        BEACH BISTRO 96        2.0               The Rockaways     Mishan
# 831   TONG SAM GYUP GOO Ee        3.0                    FLUSHING     Mishan
# 832          MUMBAI XPRESS        2.0                 FLORAL PARK     Mishan
# 833         PHIL-AM KUSINA        2.0                    ROSEBANK     Mishan
#
# ...

# %%
df['g_lat'][1],df['g_lon'][1]
# Out:
# (40.8125315, -73.9066106)

# %%
m = folium.Map(location=[nearby_res['lat'].mean(), nearby_res['lon'].mean()], zoom_start=13)
# 지도 설정; location: 중앙점(위도/경도), zoom_start: 시작 축적

# Layer of Markers
for idx, row in nearby_res.iterrows():
    lat_ = row['lat']
    lon_ = row['lon']

    folium.Marker(location=[lat_, lon_],
                  tooltip=row['name']).add_to(m)

location=[df['g_lat'][1],df['g_lon'][1]]
folium.Marker(location=location,
                  tooltip='Standard Point').add_to(m)

folium.Circle(radius=800, # meters; about 0.5 mile
              location=location,
              color="#ff7800",
              fill_color='#ffff00',
              fill_opacity=0.2).add_to(m)

m # display map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript
# ...
